# %%
print(f"SAP HANA Client for Python: {__import__("hana_ml").__version__}")
# Out:
# SAP HANA Client for Python: 2.23.25030800

# %% [markdown]
# The latest version and its documentation can be checked at https://pypi.org/project/hana-ml/#history

# %% [markdown]
# ## Load the user connection data and connect to the SAP HANA database instance
#
# 👉🏻 **Before running the next cell** make sure:
#
# 1. The content of the [./temp_user.ini](./temp_user.ini) file is copied to a file [./user.ini](./user.ini) and
# 2. the user and the password in `user.ini` file should be set to the user with database object creation.

# %%
import os, sys

file_path = './user.ini'  # Replace this with the path to your file

if os.path.exists(file_path):
    print(f"The file '{file_path}' exists.")
    from hana_ml.algorithms.pal.utility import Settings
    myhost, myport, myuser, mypwd = Settings.load_config(file_path)
    if myhost == '' or myport == 0 or myuser == '' or mypwd == '':
        print("At least one required connection parameter is empty.")
    else:
        print(f"Connection to SAP HANA db at {myhost}:{myport} \nwill be attempted for the user {myuser}")
else:
    sys.exit(f"The file '{file_path}' does not exist! Create and configure it first.")
# Out:
# The file './user.ini' exists.
# Connection to SAP HANA db at c5889dd5-e0f6-4930-8408-94d53ca61dbf.hna0.prod-us10.hanacloud.ondemand.com:443
# will be attempted for the user SANDBOX

# %%
from hana_ml import dataframe as hdf

myconn=hdf.ConnectionContext(
    address=myhost, 
    port=myport, 
    user=myuser,
    password=mypwd
)
print(f"Connected to SAP HANA db version {myconn.hana_version()} \nat {myhost}:{myport} as user {myuser}")
# Out:
# Connected to SAP HANA db version 4.00.000.00.1740475414 (fa/CE2024.40)
# at c5889dd5-e0f6-4930-8408-94d53ca61dbf.hna0.prod-us10.hanacloud.ondemand.com:443 as user SANDBOX

# %% [markdown]
# ## Create a schema for HANA-ML CodeJam

# %%
schemas=("TITANIC", "VECTORS")

# %%
for schema in schemas:
    if not myconn.has_schema(schema):
        myconn.create_schema(schema)
        print(f"Schema {schema} created")
    else: print (f"Schema {schema} already exists")
# Out:
# Schema TITANIC already exists
# Schema VECTORS already exists

# %% [markdown]
# # Load Titanic dataset - Train part

# %%
import pandas as pd

# %%
df_titanic_train = pd.read_csv(
    'https://raw.githubusercontent.com/SAP-samples/sap-tech-bytes/2021-07-07-predictive-scenarios/data/original/train.csv'
).convert_dtypes()

# %%
df_titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_titanic_train.columns=['PassengerId', 'Survived', 'PClass', 'Name', 'Gender', 'Age', 'SibSp', 'ParCh', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df_titanic_train.dtypes
# Out:
# PassengerId             Int64
# Survived                Int64
# PClass                  Int64
# Name           string[python]
# Gender         string[python]
# Age                   Float64
# SibSp                   Int64
# ParCh                   Int64
# Ticket         string[python]
# Fare                  Float64
# Cabin          string[python]
# Embarked       string[python]
# dtype: object

# %%
df_titanic_train.describe(
    include='all'
)
# Out:
#         PassengerId  Survived    PClass                     Name Gender  \
# count         891.0     891.0     891.0                      891    891
# unique         <NA>      <NA>      <NA>                      891      2
# top            <NA>      <NA>      <NA>  Braund, Mr. Owen Harris   male
# freq           <NA>      <NA>      <NA>                        1    577
# mean          446.0  0.383838  2.308642                      NaN    NaN
# std      257.353842  0.486592  0.836071                      NaN    NaN
# min             1.0       0.0       1.0                      NaN    NaN
# 25%           223.5       0.0       2.0                      NaN    NaN
# 50%           446.0       0.0       3.0                      NaN    NaN
# 75%           668.5       1.0       3.0                      NaN    NaN
# max           891.0       1.0       3.0                      NaN    NaN
#
#               Age     SibSp     ParCh  Ticket       Fare    Cabin Embarked
# count       714.0     891.0     891.0     891      891.0      204      889
# unique       <NA>      <NA>      <NA>     681       <NA>      147        3
# top          <NA>      <NA>      <NA>  347082       <NA>  B96 B98        S
# freq         <NA>      <NA>      <NA>       7       <NA>        4      644
# mean    29.699118  0.523008  0.381594     NaN  32.204208      NaN      NaN
# std     14.526497  1.102743  0.806057     NaN  49.693429      NaN      NaN
# min          0.42       0.0       0.0     NaN        0.0      NaN      NaN
# 25%        20.125       0.0       0.0     NaN     7.9104      NaN      NaN
# 50%          28.0       0.0       0.0     NaN    14.4542      NaN      NaN
# 75%          38.0       1.0       0.0     NaN       31.0      NaN      NaN
# max          80.0       8.0       6.0     NaN   512.3292      NaN      NaN

# %%
hdf_titanic_train=hdf.create_dataframe_from_pandas(
    connection_context=myconn, 
    pandas_df=df_titanic_train, 
    table_name='DATA_LABELED', schema='TITANIC',
    force=True, primary_key='PassengerId',
    # table_structure={#'PassengerId':'SMALLINT', 
    #                  #'Survived':'TINYINT', 
    #                  'PClass':'TINYINT', 
    #                  'Name':'VARCHAR(100)', 
    #                  'Gender':'VARCHAR(10)',
    #                  'Age':'REAL', 
    #                  'SibSp':'TINYINT', 
    #                  'ParCh':'TINYINT', 
    #                  'Ticket':'VARCHAR(30)', 
    #                  'Fare':'REAL', 
    #                  'Cabin':'VARCHAR(30)', 
    #                  'Embarked':'VARCHAR(1)'}
)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.67s/it]

# %%
hdf_titanic_train.describe().collect()
# Out:
#          column  count  unique  nulls        mean         std   min       max  \
# 0   PassengerId    891     891      0  446.000000  257.353842  1.00  891.0000
# 1      Survived    891       2      0    0.383838    0.486592  0.00    1.0000
# 2        PClass    891       3      0    2.308642    0.836071  1.00    3.0000
# 3           Age    714      88    177   29.699118   14.526497  0.42   80.0000
# 4         SibSp    891       7      0    0.523008    1.102743  0.00    8.0000
# 5         ParCh    891       7      0    0.381594    0.806057  0.00    6.0000
# 6          Fare    891     248      0   32.204208   49.693429  0.00  512.3292
# 7          Name    891     891      0         NaN         NaN   NaN       NaN
# 8        Gender    891       2      0         NaN         NaN   NaN       NaN
# 9        Ticket    891     681      0         NaN         NaN   NaN       NaN
# 10        Cabin    204     147    687         NaN         NaN   NaN       NaN
# 11     Embarked    889       3      2         NaN         NaN   NaN       NaN
#
#       median  25_percent_cont  25_percent_disc  50_percent_cont  \
# 0   446.0000         223.5000         223.0000         446.0000
# 1     0.0000           0.0000           0.0000           0.0000
# 2     3.0000           2.0000           2.0000           3.0000
# 3    28.0000          20.1250          20.0000          28.0000
# 4     0.0000           0.0000           0.0000           0.0000
# 5     0.0000           0.0000           0.0000           0.0000
# 6    14.4542           7.9104           7.8958          14.4542
# 7        NaN              NaN              NaN              NaN
# 8        NaN              NaN              NaN              NaN
# 9        NaN              NaN              NaN              NaN
# 10       NaN              NaN              NaN              NaN
# 11       NaN              NaN              NaN              NaN
#
#     50_percent_disc  75_percent_cont  75_percent_disc
# 0          446.0000            668.5            669.0
# 1            0.0000              1.0              1.0
# 2            3.0000              3.0              3.0
# 3           28.0000             38.0             38.0
# 4            0.0000              1.0              1.0
# 5            0.0000              0.0              0.0
# 6           14.4542             31.0             31.0
# 7               NaN              NaN              NaN
# 8               NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 10              NaN              NaN              NaN
# 11              NaN              NaN              NaN

# %% [markdown]
# # Load Titanic dataset - Test part

# %%
df_titanic_test = pd.read_csv(
    'https://raw.githubusercontent.com/SAP-samples/sap-tech-bytes/2021-07-07-predictive-scenarios/data/original/test.csv'
).convert_dtypes()

# %%
df_titanic_test.columns=['PassengerId', 'PClass', 'Name', 'Gender', 'Age', 'SibSp', 'ParCh', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df_titanic_test.describe(
    include='all'
)
# Out:
#         PassengerId    PClass              Name Gender        Age     SibSp  \
# count         418.0     418.0               418    418      332.0     418.0
# unique         <NA>      <NA>               418      2       <NA>      <NA>
# top            <NA>      <NA>  Kelly, Mr. James   male       <NA>      <NA>
# freq           <NA>      <NA>                 1    266       <NA>      <NA>
# mean         1100.5   2.26555               NaN    NaN   30.27259  0.447368
# std      120.810458  0.841838               NaN    NaN  14.181209   0.89676
# min           892.0       1.0               NaN    NaN       0.17       0.0
# 25%          996.25       1.0               NaN    NaN       21.0       0.0
# 50%          1100.5       3.0               NaN    NaN       27.0       0.0
# 75%         1204.75       3.0               NaN    NaN       39.0       1.0
# max          1309.0       3.0               NaN    NaN       76.0       8.0
#
#            ParCh    Ticket       Fare            Cabin Embarked
# count      418.0       418      417.0               91      418
# unique      <NA>       363       <NA>               76        3
# top         <NA>  PC 17608       <NA>  B57 B59 B63 B66        S
# freq        <NA>         5       <NA>                3      270
# mean    0.392344       NaN  35.627188              NaN      NaN
# std     0.981429       NaN  55.907576              NaN      NaN
# min          0.0       NaN        0.0              NaN      NaN
# 25%          0.0       NaN     7.8958              NaN      NaN
# 50%          0.0       NaN    14.4542              NaN      NaN
# 75%          0.0       NaN       31.5              NaN      NaN
# max          9.0       NaN   512.3292              NaN      NaN

# %%
df_titanic_test.dtypes
# Out:
# PassengerId             Int64
# PClass                  Int64
# Name           string[python]
# Gender         string[python]
# Age                   Float64
# SibSp                   Int64
# ParCh                   Int64
# Ticket         string[python]
# Fare                  Float64
# Cabin          string[python]
# Embarked       string[python]
# dtype: object

# %%
hdf_titanic_test=hdf.create_dataframe_from_pandas(
    connection_context=myconn, 
    pandas_df=df_titanic_test, 
    table_name='DATA_TO_PREDICT', schema='TITANIC',
    force=True, primary_key='PassengerId',
    # table_structure={'PassengerId':'SMALLINT',
    #                  'PClass':'TINYINT', 
    #                  'Name':'VARCHAR(100)', 
    #                  'Gender':'VARCHAR(10)',
    #                  'Age':'REAL', 
    #                  'SibSp':'TINYINT', 
    #                  'ParCh':'TINYINT', 
    #                  'Ticket':'VARCHAR(30)', 
    #                  'Fare':'REAL', 
    #                  'Cabin':'VARCHAR(30)', 
    #                  'Embarked':'VARCHAR(1)'}
)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]

# %%
hdf_titanic_test.describe().collect()
# Out:
#          column  count  unique  nulls         mean         std     min  \
# 0   PassengerId    418     418      0  1100.500000  120.810457  892.00
# 1        PClass    418       3      0     2.265550    0.841837    1.00
# 2           Age    332      79     86    30.272590   14.181209    0.17
# 3         SibSp    418       7      0     0.447368    0.896759    0.00
# 4         ParCh    418       8      0     0.392344    0.981428    0.00
# 5          Fare    417     169      1    35.627188   55.907576    0.00
# 6          Name    418     418      0          NaN         NaN     NaN
# 7        Gender    418       2      0          NaN         NaN     NaN
# 8        Ticket    418     363      0          NaN         NaN     NaN
# 9         Cabin     91      76    327          NaN         NaN     NaN
# 10     Embarked    418       3      0          NaN         NaN     NaN
#
#           max     median  25_percent_cont  25_percent_disc  50_percent_cont  \
# 0   1309.0000  1101.0000         996.2500         996.0000        1100.5000
# 1      3.0000     3.0000           1.0000           1.0000           3.0000
# 2     76.0000    27.0000          21.0000          21.0000          27.0000
# 3      8.0000     0.0000           0.0000           0.0000           0.0000
# 4      9.0000     0.0000           0.0000           0.0000           0.0000
# 5    512.3292    14.4542           7.8958           7.8958          14.4542
# 6         NaN        NaN              NaN              NaN              NaN
# 7         NaN        NaN              NaN              NaN              NaN
# 8         NaN        NaN              NaN              NaN              NaN
# 9         NaN        NaN              NaN              NaN              NaN
# 10        NaN        NaN              NaN              NaN              NaN
#
#     50_percent_disc  75_percent_cont  75_percent_disc
# 0         1100.0000          1204.75           1205.0
# 1            3.0000             3.00              3.0
# 2           27.0000            39.00             39.0
# 3            0.0000             1.00              1.0
# 4            0.0000             0.00              0.0
# 5           14.4542            31.50             31.5
# 6               NaN              NaN              NaN
# 7               NaN              NaN              NaN
# 8               NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 10              NaN              NaN              NaN

# %% [markdown]
# # Load Titanic dataset - Complete

# %%
df_titanic_complete = pd.read_csv(
    'https://raw.githubusercontent.com/SAP-samples/sap-tech-bytes/2021-07-07-predictive-scenarios/data/original/titanic3.csv'
).convert_dtypes()

# %%
df_titanic_complete.columns=['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home_dest']

# %%
df_titanic_complete[['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked']].describe(
    include='all'
)
# Out:
#           pclass  survived                  name gender        age     sibsp  \
# count     1309.0    1309.0                  1309   1309     1046.0    1309.0
# unique      <NA>      <NA>                  1307      2       <NA>      <NA>
# top         <NA>      <NA>  Connolly, Miss. Kate   male       <NA>      <NA>
# freq        <NA>      <NA>                     2    843       <NA>      <NA>
# mean    2.294882  0.381971                   NaN    NaN  29.881138  0.498854
# std     0.837836  0.486055                   NaN    NaN  14.413493  1.041658
# min          1.0       0.0                   NaN    NaN       0.17       0.0
# 25%          2.0       0.0                   NaN    NaN       21.0       0.0
# 50%          3.0       0.0                   NaN    NaN       28.0       0.0
# 75%          3.0       1.0                   NaN    NaN       39.0       1.0
# max          3.0       1.0                   NaN    NaN       80.0       8.0
#
#            parch    ticket       fare        cabin embarked
# count     1309.0      1309     1308.0          295     1307
# unique      <NA>       929       <NA>          186        3
# top         <NA>  CA. 2343       <NA>  C23 C25 C27        S
# freq        <NA>        11       <NA>            6      914
# mean    0.385027       NaN  33.295479          NaN      NaN
# std      0.86556       NaN  51.758668          NaN      NaN
# min          0.0       NaN        0.0          NaN      NaN
# 25%          0.0       NaN     7.8958          NaN      NaN
# 50%          0.0       NaN    14.4542          NaN      NaN
# 75%          0.0       NaN     31.275          NaN      NaN
# max          9.0       NaN   512.3292          NaN      NaN

# %%
hdf_titanic_test.count() + hdf_titanic_train.count()
# Out:
# 1309

# %%
df_titanic_complete.dtypes
# Out:
# pclass                Int64
# survived              Int64
# name         string[python]
# gender       string[python]
# age                 Float64
# sibsp                 Int64
# parch                 Int64
# ticket       string[python]
# fare                Float64
# cabin        string[python]
# embarked     string[python]
# boat         string[python]
# body                  Int64
# home_dest    string[python]
# dtype: object

# %% [markdown]
# Check if names are unique to use as a key in the database

# %%
df_titanic_complete[df_titanic_complete.duplicated('name', keep=False)]
# Out:
#      pclass  survived                  name  gender   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male  44.0      0      0
#
#      ticket    fare cabin embarked  boat  body home_dest
# 725  370373    7.75  <NA>        Q    13  <NA>   Ireland
# 726  330972  7.6292  <NA>        Q  <NA>  <NA>   Ireland
# 924  330911  7.8292  <NA>        Q  <NA>    70      <NA>
# 925  363592    8.05  <NA>        S  <NA>  <NA>      <NA>

# %%
hdf_titanic_complete=hdf.create_dataframe_from_pandas(
    connection_context=myconn, 
    pandas_df=df_titanic_complete[['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked']], 
    table_name='DATA_COMPLETE', schema='TITANIC',
    force=True, primary_key=['name', 'ticket'],
    # table_structure={'pclass':'TINYINT', 
    #                  'survived':'TINYINT', 
    #                  'name':'VARCHAR(100)', 
    #                  'gender':'VARCHAR(10)',
    #                  'age':'REAL', 
    #                  'sibsp':'TINYINT', 
    #                  'parch':'TINYINT', 
    #                  'ticket':'VARCHAR(30)', 
    #                  'fare':'REAL', 
    #                  'cabin':'VARCHAR(30)', 
    #                  'embarked':'VARCHAR(1)'}
)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]

# %%
hdf_titanic_complete.describe().collect()
# Out:
#       column  count  unique  nulls       mean        std   min       max  \
# 0     pclass   1309       3      0   2.294882   0.837836  1.00    3.0000
# 1   survived   1309       2      0   0.381971   0.486055  0.00    1.0000
# 2        age   1046      98    263  29.881138  14.413493  0.17   80.0000
# 3      sibsp   1309       7      0   0.498854   1.041658  0.00    8.0000
# 4      parch   1309       8      0   0.385027   0.865560  0.00    9.0000
# 5       fare   1308     281      1  33.295479  51.758668  0.00  512.3292
# 6       name   1309    1307      0        NaN        NaN   NaN       NaN
# 7     gender   1309       2      0        NaN        NaN   NaN       NaN
# 8     ticket   1309     929      0        NaN        NaN   NaN       NaN
# 9      cabin    295     186   1014        NaN        NaN   NaN       NaN
# 10  embarked   1307       3      2        NaN        NaN   NaN       NaN
#
#      median  25_percent_cont  25_percent_disc  50_percent_cont  \
# 0    3.0000           2.0000           2.0000           3.0000
# 1    0.0000           0.0000           0.0000           0.0000
# 2   28.0000          21.0000          21.0000          28.0000
# 3    0.0000           0.0000           0.0000           0.0000
# 4    0.0000           0.0000           0.0000           0.0000
# 5   14.4542           7.8958           7.8958          14.4542
# 6       NaN              NaN              NaN              NaN
# 7       NaN              NaN              NaN              NaN
# 8       NaN              NaN              NaN              NaN
# 9       NaN              NaN              NaN              NaN
# 10      NaN              NaN              NaN              NaN
#
#     50_percent_disc  75_percent_cont  75_percent_disc
# 0            3.0000            3.000            3.000
# 1            0.0000            1.000            1.000
# 2           28.0000           39.000           39.000
# 3            0.0000            1.000            1.000
# 4            0.0000            0.000            0.000
# 5           14.4542           31.275           31.275
# 6               NaN              NaN              NaN
# 7               NaN              NaN              NaN
# 8               NaN              NaN              NaN
# 9               NaN              NaN              NaN
# 10              NaN              NaN              NaN

# %%
hdf_titanic_complete.get_table_structure()
# Out:
# {'pclass': 'INT',
#  'survived': 'INT',
#  'name': 'NVARCHAR(5000)',
#  'gender': 'NVARCHAR(5000)',
#  'age': 'DOUBLE',
#  'sibsp': 'INT',
#  'parch': 'INT',
#  'ticket': 'NVARCHAR(5000)',
#  'fare': 'DOUBLE',
#  'cabin': 'NVARCHAR(5000)',
#  'embarked': 'NVARCHAR(5000)'}
